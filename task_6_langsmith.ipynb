# %%
pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 550.1/550.1 kB 11.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.0
#     Uninstalling langchain-core-1.4.0:
#       Successfully uninstalled langchain-core-1.4.0
# ...

# %%
pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.8 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata


os.environ["LANGSMITH_API_KEY"] = userdata.get("paste secret code name")
os.environ["OPENAI_API_KEY"] = userdata.get("paste secret code name")
os.environ["GOOGLE_API_KEY"] = userdata.get("paste api key name")


os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "my-langchain-project"


from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")


response = llm.invoke("Explain how LangSmith tracing works in one sentence.")
print(response.content)
# Out:
# LangSmith tracing automatically captures and visualizes the full execution path of your LLM applications, including all LLM calls, chain steps, and intermediate inputs/outputs, to enable debugging, monitoring, and evaluation.

# %%
import os
from google.colab import userdata
from langsmith import Client
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI




os.environ["LANGSMITH_API_KEY"] = userdata.get("api name")
os.environ["GEMINI_API_KEY"] = userdata.get("api key")




client = Client()




model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
prompt = ChatPromptTemplate.from_template("Tell me a brief {style} joke about {topic}.")




chain = prompt | model




url = client.push_prompt("gemini-joke-generator", object=chain)


print(f"Successfully pushed prompt! Access it here: {url}")
# Out:
# Successfully pushed prompt! Access it here: https://smith.langchain.com/prompts/gemini-joke-generator/edf0e7ae?organizationId=ec01ad8a-aecd-461a-bdff-4ef12bddc82f
